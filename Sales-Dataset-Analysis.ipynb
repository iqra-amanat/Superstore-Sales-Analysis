# %% [markdown]
# # Sales-DataAnalysis

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load Data

# %%
data=pd.read_csv("C:\\Users\\Administrator\\Downloads\\train.csv~1\\train.csv")
data.head()
# check dataset information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %% [markdown]
#  ### check for missing value

# %%
 #check for missing value
data.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %% [markdown]
# ### Get basic Statistics

# %%
#Get basic Statistics
data.describe()
# Out:
#             Row ID   Postal Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %% [markdown]
# ### Group by Customer ID and Customer Name to get total sales

# %%
# Group by Customer ID and Customer Name to get total sales
top_customers = data.groupby(['Customer ID', 'Customer Name'])['Sales'].sum().nlargest(10).reset_index()

# %% [markdown]
# ### Plot top customers

# %%
# Plot top customers
plt.figure(figsize=(10, 6))
sns.barplot(data=top_customers, x='Sales', y='Customer Name')
plt.title('Top 10 Customers by Sales')
plt.xlabel('Total Sales')
plt.ylabel('Customer Name')
plt.show()

# %% [markdown]
# ### Total sales by segment

# %%
# Total sales by segment
segment_sales = data.groupby('Segment')['Sales'].sum().reset_index()

# %% [markdown]
# ### Plot segment sales

# %%
# Plot segment sales
plt.figure(figsize=(8, 5))
sns.barplot(data=segment_sales, x='Segment', y='Sales',color="y")
plt.title('Sales by Segment')
plt.xlabel('Segment')
plt.ylabel('Total Sales')
plt.show()

# %% [markdown]
# ### Total sales by region

# %%
# Total sales by region
region_sales = data.groupby('Region')['Sales'].sum().reset_index()

# %% [markdown]
# ### Plot region sales

# %%
# Plot region sales
plt.figure(figsize=(8, 5))
sns.barplot(data=region_sales, x='Sales', y='Region',color="g")
plt.title('Sales by Region')
plt.xlabel('Total Sales')
plt.ylabel('Region')
plt.show()

# %% [markdown]
# ### Total sales by category and sub-category

# %%
# Total sales by category and sub-category
category_sales = data.groupby(['Category', 'Sub-Category'])['Sales'].sum().reset_index()

# %% [markdown]
# ### Plot sales by category

# %%
# Plot sales by category
plt.figure(figsize=(12, 6))
sns.barplot(data=category_sales, x='Category', y='Sales', hue='Sub-Category', palette='mako')
plt.title('Sales by Category and Sub-Category')
plt.xlabel('Category')
plt.ylabel('Total Sales')
plt.legend(title='Sub-Category', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# # Sales-DataAnalysis Project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_csv("C:\\Users\\Administrator\\Downloads\\train.csv~1\\train.csv")
data.head()
# check dataset information
data.info()

# check for missing value
data.isnull().sum()

#Get basic Statistics
data.describe()

# Group by Customer ID and Customer Name to get total sales
top_customers = data.groupby(['Customer ID', 'Customer Name'])['Sales'].sum().nlargest(10).reset_index()

# Plot top customers
plt.figure(figsize=(10, 6))
sns.barplot(data=top_customers, x='Sales', y='Customer Name')
plt.title('Top 10 Customers by Sales')
plt.xlabel('Total Sales')
plt.ylabel('Customer Name')
plt.show()

# Total sales by segment
segment_sales = data.groupby('Segment')['Sales'].sum().reset_index()

# Plot segment sales
plt.figure(figsize=(8, 5))
sns.barplot(data=segment_sales, x='Segment', y='Sales',color="y")
plt.title('Sales by Segment')
plt.xlabel('Segment')
plt.ylabel('Total Sales')
plt.show()

# Total sales by region
region_sales = data.groupby('Region')['Sales'].sum().reset_index()

# Plot region sales
plt.figure(figsize=(8, 5))
sns.barplot(data=region_sales, x='Sales', y='Region',color="g")
plt.title('Sales by Region')
plt.xlabel('Total Sales')
plt.ylabel('Region')
plt.show()

# Total sales by category and sub-category
category_sales = data.groupby(['Category', 'Sub-Category'])['Sales'].sum().reset_index()

# Plot sales by category
plt.figure(figsize=(12, 6))
sns.barplot(data=category_sales, x='Category', y='Sales', hue='Sub-Category', palette='mako')
plt.title('Sales by Category and Sub-Category')
plt.xlabel('Category')
plt.ylabel('Total Sales')
plt.legend(title='Sub-Category', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...
